# %% [markdown]
# ## Preprocess Baseline
# In this notebook we show how to correct the baseline of a neural signal and
# apply normalisation and filtering.  These steps reduce slow drifts and
# heteroscedasticity, making the data more amenable to downstream analyses.

# %%
import numpy as np
from neuroengine.preprocess import baseline_correction, zscore_normalization

# Suppose `signal` is a 1D NumPy array containing your time series
# corrected = baseline_correction(signal, window=100)
# normalised = zscore_normalization(corrected)
