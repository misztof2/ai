# %% [markdown]
# ## Load and Inspect Data
# This notebook demonstrates how to use the Neuro Data Engine to load raw neural
# recordings from disk and inspect their basic properties.  You can adapt this
# template to suit your own data formats and analysis needs.

# %%
# Example: load a CSV file
from neuroengine.io import load_csv

# Replace with the path to your own data file
# data = load_csv('path/to/raw_data.csv')
# print(f'Data shape: {data.shape}')
