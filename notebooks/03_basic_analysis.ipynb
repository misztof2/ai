# %% [markdown]
# ## Basic Analysis
# This notebook provides examples of computing simple statistics and detecting
# patterns in neural signals using the Neuro Data Engine's `analysis` module.
# You can extend these examples to explore your own experimental hypotheses.

# %%
import numpy as np
from neuroengine.analysis import stats, patterns

# Example signal
# signal = np.random.randn(1000)
# Compute mean and variance
# m = stats.mean(signal)
# v = stats.variance(signal)

# Detect peaks above a threshold
# peak_indices = patterns.detect_peaks(signal, threshold=2.0)
